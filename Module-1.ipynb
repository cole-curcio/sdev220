# %% [markdown]
# # Chapter 3 - Things to Do
#
# **Table of Contents**
#
# - [3.1](#31---numbers-of-seconds-in-an-hour)
# - [3.2](#32---assign-seconds-per-hour)
# - [3.3](#33---seconds-in-day-variable)
# - [3.4](#34---caculate-seconds-per-day)
# - [3.5](#35---divide-seconds-per-day)
# - [3.6](#36---divide-seconds-per-day-and-hour)

# %% [markdown]
# # 3.1
#
# How many seconds are in an hour? Use the interactive interpreter as a calculator and multiply the number of seconds in a minute (60) by the number of minutes in an hour (also 60).

# %%
seconds_in_minutes: int = 60
minutes_in_hour: int = 60
seconds_in_hour = seconds_in_minutes * minutes_in_hour
print("Result for seconds that are in an hour:", seconds_in_hour)
# Out:
# Result for seconds that are in an hour: 3600

# %% [markdown]
# # 3.2
#
# Assign the result from the previous task (seconds in an hour) to a variable called seconds_per_hour.

# %%
seconds_per_hour: int = seconds_in_hour
print("Result for seconds that are in an hour:", seconds_per_hour)
# Out:
# Result for seconds that are in an hour: 3600

# %% [markdown]
# # 3.3
#
# How many seconds are in a day? Use your seconds_per_hour variable.

# %%
hours_in_day: int = 24 
print("Result for seconds in an day:", hours_in_day * seconds_per_hour)
# Out:
# Result for seconds in an day: 86400

# %% [markdown]
# # 3.4
#
# Calculate seconds per day again, but this time save the result in a variable called seconds_per_day.

# %%
seconds_per_day: int = hours_in_day
print("Result for seconds per day:", seconds_per_day * hours_in_day)
# Out:
# Result for seconds per day: 576

# %% [markdown]
# # 3.5
#
# Divide seconds_per_day by seconds_per_hour. Use floating-point (/) division.

# %%
seconds_per_day / seconds_per_hour
print("Result for the division:", seconds_per_day)
# Out:
# Result for the division: 24

# %% [markdown]
# # 3.6
#
# Divide seconds_per_day by seconds_per_hour, using integer (//) division. Did this number agree with the floating-point value from the previous question, aside from the final .0?

# %%
seconds_per_day // seconds_per_hour
print("Result for the devision:", seconds_per_day)
# Out:
# Result for the devision: 24
